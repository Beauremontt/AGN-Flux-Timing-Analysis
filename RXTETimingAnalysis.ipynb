# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy.stats import LombScargle
#This loads the text files saved from the UCSD wesbite
#AGN = np.genfromtxt('MKN590_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('1H0323+342_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('1ES0647+250_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('NGC2992_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('CTA102_2-10', skip_header = 7, skip_footer = 3)
#AGN = np.genfromtxt('3C66A_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('3C454.3_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('NRAO530_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('NGC6251_2-10', skip_header = 0, skip_footer = 0)
#Skip_header is the number of lines to skip at the beginning of the file
#AGN = np.genfromtxt('1ES1101-232_2-10', skip_header = 27, skip_footer = 0)
#AGN = np.genfromtxt('1ES1101-232_2-10', skip_header = 0, skip_footer = 79)
AGN = np.genfromtxt('PG0052+251_2-10', skip_header = 17, skip_footer = 0)
#AGN = np.genfromtxt('PKS0829+046_2-10', skip_header = 0, skip_footer = 28)
#AGN = np.genfromtxt('PKS0829+046_2-10', skip_header = 70, skip_footer = 0)
#AGN = np.genfromtxt('PKS0829+046_2-10', skip_header = 0, skip_footer = 0)
#Skip_footer is the number of lines to skip at the end of the file
#AGN = np.genfromtxt('PKS1622-297_2-10', skip_header = 41)
#AGN = np.genfromtxt('PKS1622-297_2-10', skip_footer = 49)
#AGN = np.genfromtxt('MKN279_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('MKN279_2-10', skip_header = 16, skip_footer = 23)
#AGN = np.genfromtxt('MKN279_2-10', skip_header = 46)
#AGN = np.genfromtxt('MCG-2-58-22_2-10', skip_header = 10, skip_footer = 15)
#AGN = np.genfromtxt('MCG-2-58-22_2-10', skip_header = 10, skip_footer = 0)
#AGN = np.genfromtxt('1ES2344+514_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('4C29.45_2-10', skip_header = 21, skip_footer = 14)
#AGN = np.genfromtxt('IRAS18325-5926_2-10', skip_header = 11, skip_footer = 10)
#AGN = np.genfromtxt('IRAS18325-5926_2-10', skip_header = 11, skip_footer = 0)
#AGN = np.genfromtxt('NGC2110_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('NGC7582_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('RGBJ0152+017_2-10', skip_header = 13)
#AGN = np.genfromtxt('RGBJ0152+017_2-10')
#AGN = np.genfromtxt('1ES0806+524_2-10', skip_header = 11, skip_footer = 7)
#AGN = np.genfromtxt('1ES0806+524_2-10', skip_header = 22, skip_footer = 0)
#AGN = np.genfromtxt('NGC526A_2-10', skip_header = 18, skip_footer = 0)
#AGN = np.genfromtxt('NGC526A_2-10', skip_header = 0, skip_footer = 10)
#AGN = np.genfromtxt('PG1553+113_2-10', skip_header = 8)
#AGN = np.genfromtxt('S50716+714_2-10', skip_header = 39)
#AGN = np.genfromtxt('1ES0229+200_2-10', skip_header = 0)
#AGN = np.genfromtxt('4C71.07_2-10', skip_header = 0)
#AGN = np.genfromtxt('3C273_2-10', skip_header = 247)
#AGN = np.genfromtxt('3C279_2-10', skip_header = 0)
#AGN = np.genfromtxt('MKN421_2-10', skip_header = 0)
#AGN = np.genfromtxt('PKS1510-089_2-10', skip_header = 476)
#AGN = np.genfromtxt('PKS1510-089_2-10', skip_header = 650)
#AGN = np.genfromtxt('NGC4051_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('CenA_2-10', skip_header = 137, skip_footer = 0)
#AGN = np.genfromtxt('BLLac_2-10', skip_header = 0, skip_footer = 0)
#AGN = np.genfromtxt('BLLac_2-10', skip_header = 250, skip_footer = 0)
#AGN = np.genfromtxt('NGC4945_2-10', skip_header = 155, skip_footer = 204)
#AGN = np.genfromtxt('NGC4945_2-10', skip_header = 82, skip_footer = 387)
#AGN = np.genfromtxt('NGC4945_2-10', skip_footer = 491)
#AGN = np.genfromtxt('SwiftBAT.NGC4945.lc.txt', skip_header = 298, skip_footer = 4479)
#AGN = np.genfromtxt('SwiftBAT.NGC4945.lc.txt', skip_header = 444, skip_footer = 4479)
#AGN = np.genfromtxt('SwiftBAT.NGC4945.lc.txt', skip_header = 5, skip_footer = 365)
#AGN = np.genfromtxt('NGC4258_2-10', skip_header = 455, skip_footer = 0)
#AGN = np.genfromtxt('NGC4258_2-10', skip_header = 70, skip_footer = 797)
#AGN = np.genfromtxt('NGC4258_2-10', skip_header = 0, skip_footer = 1182)
#AGN = np.genfromtxt('NGC4945_2-10')
#AGN = np.genfromtxt('NGC4945_2-10', skip_header = 348)
#AGN = np.genfromtxt('NGC4945_2-4', skip_header = 447)
#AGN = np.genfromtxt('NGC4945_2-10', skip_header = 448)
#AGN = np.genfromtxt('3C111_2-10', skip_header = 40)
#AGN = np.genfromtxt('3C111_2-10', skip_header = 40, skip_footer = 877)
#AGN = np.genfromtxt('3C111_2-10', skip_header = 934)
#AGN = np.genfromtxt('3C111_2-10', skip_header = 550, skip_footer = 371)
#AGN = np.genfromtxt('3C111_2-10', skip_header = 130, skip_footer = 451)
#AGN = np.genfromtxt('3C111_2-10', skip_header = 275, skip_footer = 495)
#AGN = np.genfromtxt('3C111_2-10', skip_header = 655, skip_footer = 267)
#AGN = np.genfromtxt('ARK564_2-10', skip_header = 11)
#AGN = np.genfromtxt('IC4329A_2-10', skip_header = 10, skip_footer = 516)
#AGN = np.genfromtxt('IC4329A_2-10', skip_header = 74)
#AGN = np.genfromtxt('MKN110_2-10', skip_header = 44)
#AGN = np.genfromtxt('MKN110_2-10', skip_footer = 1394)
#AGN = np.genfromtxt('MKN110_2-10', skip_header = 44, skip_footer = 909)
#AGN = np.genfromtxt('MKN110_2-10', skip_header = 639)
#AGN = np.genfromtxt('MKN110_2-10', skip_header = 665)
#AGN = np.genfromtxt('MKN509_2-10', skip_header = 35)
#AGN = np.genfromtxt('NGC3227_2-10', skip_header = 23)
#AGN = np.genfromtxt('3C120_2-10')
#AGN = np.genfromtxt('MCG-6-30-15_2-10')
#AGN = np.genfromtxt('MKN766_2-10', skip_header = 20)
#AGN = np.genfromtxt('PKS1510-089_2-10')
#AGN = np.genfromtxt('H1426+428_2-10', skip_header = 29, skip_footer = 13)
#AGN = np.genfromtxt('H1426+428_2-10')
#This sets up the values
x = 86400*AGN[:,0]  #This is the first column of the data set (MJD midpoit of observation)
y = AGN[:,1] #Second column of the data set (Flux)
dy = AGN[:,2] #Third column of the data set (the uncertainty)

#Put Thomas test on same graph
yy = 0 * x + 1 #Need to set the y values to one, in order to have the y axis be zero
dyy = 0 * x + 42
ffrequency, ppower = LombScargle(x, yy, dyy).autopower(nyquist_factor = 2)
#Gets timespan and spacing of data
NumData = len (x)
Span = x[NumData - 1] - x[0]
MeanSpacing = Span / (NumData - 1)

#This sets up the periodogram
frequency, power = LombScargle(x, y, dy).autopower(nyquist_factor = 2)

#This gives the number of points in the periodogram
A = len (frequency)
B = len (power)

#Getting the averages of the error and the flux in order to find the percent error
Error = np.mean(dy)
Mean = np.mean(y)

#The first plot is for the light curve
plt.subplots(1,1,figsize=(12,8))
plt.title('Light Curve', fontsize=24)
plt.xlabel('MJD', fontsize=24)
plt.ylabel('Flux', fontsize=24)
#plt.xlim((52750,52775))
#plt.ylim((2e-12,9e-12))
plt.tick_params(labelsize=18)
#plt.ylim(-.0050,0.015)
#plt.plot(x/86400, y)
plt.errorbar(x/86400,y,yerr=dy,fmt='_k',ecolor='c',elinewidth=1);
#plt.savefig('NGC6251_LC.png')

array = frequency, power

#Finds the maximum and the minimum of the periodogram
np.max(array), np.min(array)
result = np.where(power == np.amax(power))
item = result[0]
fofmax = frequency[item]
period = 1/(fofmax*86400)
#Finds the False Alarm Probability [Horne & Baliunas, 1986]
N_i = -6.392 + 1.193 * B + 0.00098 * B ** 2
Mu = np.mean(power)
Sigma = np.std(power)
Z = (np.max(power) - Mu)/Sigma
FAP = 1 - (1 - np.exp(-Z)) ** N_i
altFAP = 1 - (1 - np.exp(-Z)) ** (NumData/2)

#This plot is for the power spectrum
plt.subplots(1,1,figsize=(12,8))
plt.xscale('log') #This sets the x axis as a logarithmic function
plt.yscale('log') #This sets the y axis as a logarithmic function
plt.title('Power Spectrum', fontsize=24)
plt.xlabel("Frequency", fontsize=24)
plt.ylabel('Power', fontsize=24)
#plt.xlim((1e-7,4e-7))
plt.ylim((1e-5,1))
plt.plot(ffrequency, ppower,'r', linewidth=1)
plt.plot(frequency,power)
plt.tick_params(labelsize=18)
#plt.savefig('NGC6251_LSP.png')

#This prints how many data points there are going to be in the output data file of the periodogram
print ("The count for frequency is: " ,A,)
print ("")
print ("The count for power is: " ,B,)
print ("")
#This will calculate and print out the percent error
print ("The percent error is: ",((Error/Mean)*100),)
#Prints out the maximum and minimum of the periodogram
print ("")
print ("Minimum of the Periodogram: ", np.min(array))
print ("Maximum of the Periodogram: ", np.max(array))
print ("Index = ", result, item)
print ("Frequency at Maximum Power", fofmax)
print ("Period =", period, "days")
print ("# of data points =", NumData, "Start MJD =", x[0]/86400, "End MJD =", x[NumData - 1]/86400)
print ("Data Span =", Span/86400, "days",)
print ("Mean Spacing =", MeanSpacing/86400, "days")
print ("Mean power =", Mu, "Power standard deviation =", Sigma)
print ("Number of independent frequencies [HB86] =", N_i)
print ("Nyquist-limited frequencies =", NumData/2)
print ("Z=", Z, "False Alarm Probability =", FAP)
print ("AltFAP (Nyquist) =", altFAP)
# Out:
# WARNING: AstropyDeprecationWarning: Importing LombScargle from astropy.stats has been deprecated and will no longer be supported in future. Please import this class from the astropy.timeseries module instead [astropy.stats.lombscargle]
# The count for frequency is:  725
#
# The count for power is:  725
#
# The percent error is:  10.450086572535554
#
# Minimum of the Periodogram:  3.963931384887479e-09
# Maximum of the Periodogram:  0.07897369149207235
# Index =  (array([10], dtype=int64),) [10]
# Frequency at Maximum Power [8.32425591e-08]
# Period = [139.04034429] days
# # of data points = 145 Start MJD = 53140.768414 End MJD = 53432.75313700001
# Data Span = 291.98472300000765 days
# Mean Spacing = 2.027671687500053 days
# Mean power = 0.01407604919611913 Power standard deviation = 0.015202100882139054
# Number of independent frequencies [HB86] = 1373.6455
# Nyquist-limited frequencies = 72.5
# Z= 4.268991687339837 False Alarm Probability = 0.9999999960957331
# ...
